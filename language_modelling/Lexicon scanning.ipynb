# %%
import _pickle as cPickle
import numpy as np

with open(r"/content/drive/Shareddrives/[FYP] Fake News Detection/Lexicon based study/WELFake_Lexicon1.pickle", "rb") as input_file:
  lexicon = cPickle.load(input_file)

# %%
print(lexicon['fake'])
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
for key in lexicon.keys():
  print(key)
# Out:
# fake
# true
# common
# unique_true
# unique_fake

# %%
fake = dict(sorted(lexicon['fake'].items(), key=lambda item: item[1], reverse = True)[:500])
fake
# Out:
# {'absolutely': 0.0003943144259850024,
#  'access': 0.0004089813431174918,
#  'account': 0.000491905836135797,
#  'accuse': 0.00048090564828643,
#  'act': 0.0009671703624481926,
#  'action': 0.0007920135251544256,
#  'add': 0.0008873484865156064,
#  'address': 0.0003830321820369337,
#  'administration': 0.0009936836357261542,
#  'admit': 0.00038895536010966975,
#  'agency': 0.0005438041582969133,
#  'ago': 0.0005999333219385552,
#  'agree': 0.00042449442854608635,
#  'air': 0.0004735721897201853,
#  'al': 0.0004944443410241125,
#  'allow': 0.000518983221611162,
#  'america': 0.002056188959535528,
#  'american': 0.003340954489121855,
#  'announce': 0.0005257525679800033,
#  'answer': 0.0005062906971695847,
#  'anti': 0.0008667583913103808,
#  'apparently': 0.0004543923750084684,
#  'appear': 0.000678344917377633,
#  'area': 0.0004969828459124279,
#  'arm': 0.0004555205994032754,
#  'arrest': 0.0005031880800838658,
#  'article': 0.0005849843487073641,
#  'ask': 0.0010517871920587083,
# ...

# %%
true = dict(sorted(lexicon['true'].items(), key=lambda item: item[1], reverse = True)[:500])
true
# Out:
# {'access': 0.0004069890637577366,
#  'account': 0.00048014872929726923,
#  'accuse': 0.0006746263836306488,
#  'act': 0.000923410232272085,
#  'action': 0.0008727927605962738,
#  'add': 0.0014558158655261634,
#  'address': 0.0005330204203594526,
#  'administration': 0.0017908748379551157,
#  'adviser': 0.000504125426406864,
#  'agency': 0.001242689668996432,
#  'ago': 0.0005004367037746186,
#  'agree': 0.0006660193641554097,
#  'agreement': 0.0007342607328519486,
#  'ahead': 0.0004592459677145456,
#  'aim': 0.00041948973490034576,
#  'air': 0.0006611010673124159,
#  'al': 0.0006293370668680811,
#  'allow': 0.0004721564969274044,
#  'ally': 0.000678520035298019,
#  'america': 0.0006656095060851602,
#  'american': 0.0020007221699228513,
#  'announce': 0.0006662242931905344,
#  'anti': 0.00047912408412164556,
#  'appeal': 0.0004764600066650239,
#  'appear': 0.0005160113104440991,
#  'area': 0.0007834437012818866,
#  'arm': 0.0005391682914131947,
#  'army': 0.0004879360326320094,
# ...

# %%
common = dict(sorted(lexicon['common'].items(), key=lambda item: item[1], reverse = True)[:500])
common
# Out:
# {'access': 0.00010195685954841608,
#  'account': 0.00012127406431151819,
#  'accuse': 0.00014827660860402652,
#  'act': 0.00023545625160555344,
#  'action': 0.00020969997858808392,
#  'add': 0.00030414953736067075,
#  'address': 0.00011747590423520933,
#  'administration': 0.00036385186606015073,
#  'agency': 0.00023714761976453472,
#  'ago': 0.00013557651084886876,
#  'agree': 0.00014109571220975508,
#  'agreement': 0.00013127390763742513,
#  'air': 0.00014554668104917954,
#  'al': 0.00014314315787589032,
#  'allow': 0.0001229654324704995,
#  'ally': 0.00012735705505873162,
#  'america': 0.0003126953975323658,
#  'american': 0.0006411768978818902,
#  'announce': 0.00015177803742437375,
#  'anti': 0.000160561282600838,
#  'appear': 0.0001460807973099105,
#  'area': 0.00016572440645457037,
#  'arm': 0.00012599209128130812,
#  'arrest': 0.00014112538533535125,
#  'article': 0.00010053254951980025,
#  'ask': 0.0002640908178058507,
#  'attack': 0.0004273820279615357,
# ...
